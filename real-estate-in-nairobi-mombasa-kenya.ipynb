# %% [markdown]
# ## **Import Packages**

# %%
# pip install google-search-results

# %%
# Import Packages
from bs4 import BeautifulSoup
from datetime import datetime 
import requests   
import pandas as pd 
import numpy as np
from tqdm import trange
pd.set_option('display.max_rows',1000)
import time
from google.cloud import bigquery

# %% [markdown]
# ## **Initialize Client Object**

# %%
# initialize client object
client = bigquery.Client(project='project-adrian-julius-aluoch')

# %% [markdown]
# ## **Scrape Real Estate Listings in Nairobi & Mombasa, Kenya**

# %% [markdown]
# ### **a. Apartments for Rent in Nairobi**

# %%
# Initialize DataFrame outside the loop
bigdata = pd.DataFrame()

for page in trange(1,101):
    counties = ['nairobi']
    furnished = ['true','false']
    rental_rates = ['day','month','week','year']
    
    for county in counties:
        for furnish in furnished:
            for rate in rental_rates:
                
                # specify website url 
                url = 'https://www.property24.co.ke/property-to-rent-in-'+str(county)+'-p95?rentalterm='+str(rate)+'&isfurnished='+str(furnish)+'&propertytypes=apartments-flats,townhouses&Page=' + str(page)
                req = requests.get(url).text 
                soup = BeautifulSoup(req,'lxml')
                listings = soup.find_all('span',class_='p24_content')

                for listing in listings:
                    try:
                        property_title = listing.find('span',class_='p24_propertyTitle').text.strip()
                        property_availability = 'For Rent'
                        property_location = listing.find('span',class_='p24_location').text.strip()
                        property_address = listing.find('span',class_='p24_address').text.strip()
                        floor_size = listing.find('span', class_='p24_size', title='Floor Size').text.strip()
                        furnished = furnish
                        rental_rate = rate
                        property_price = listing.find('span',class_='p24_price').text.strip()
                        last_scraped = datetime.now()
                        
                        # Create DataFrame
                        data = pd.DataFrame({
                            'county':[county],
                            'property_title':[property_title],
                            'property_availability':[property_availability],
                            'property_location':[property_location],
                            'property_address':[property_address],
                            'floor_size':[floor_size],
                            'furnished':[furnished],
                            'rental_rate':[rental_rate],
                            'property_price':[property_price],
                            'last_scraped':[last_scraped]
                        })

                        # Append data to bigdata DataFrame
                        bigdata = pd.concat([bigdata,data],ignore_index=True)
                        
                    except Exception as e:
                        pass            

# Handle Database Import Error
table_id = 'project-adrian-julius-aluoch.cronjobs.real_estate_data'
job = client.load_table_from_dataframe(bigdata,table_id)
while job.state != 'DONE':
    time.sleep(4)
    job.reload()
    print(f"Data Upload Status : {job.state}")
# Out:
# 100%|██████████| 100/100 [22:35<00:00, 13.56s/it]
# Data Upload Status : DONE

# %%
# Shape of Data Collected
bigdata.shape
# Out:
# (1758, 10)

# %%
# Apartments for Rent in Nairobi
bigdata.head()
# Out:
#     county              property_title property_availability  \
# 0  nairobi  2 Bedroom Apartment / Flat              For Rent
# 1  nairobi            Apartment / Flat              For Rent
# 2  nairobi  2 Bedroom Apartment / Flat              For Rent
# 3  nairobi  2 Bedroom Apartment / Flat              For Rent
# 4  nairobi  3 Bedroom Apartment / Flat              For Rent
#
#   property_location                             property_address floor_size  \
# 0          Kilimani  Kilimani Estate Kilimani, Kilimani, Nairobi     120 m²
# 1          Kilimani  Kilimani Estate Kilimani, Kilimani, Nairobi      39 m²
# 2          Kilimani  Kilimani Estate Kilimani, Kilimani, Nairobi     120 m²
# 3          Kilimani  Kilimani Estate Kilimani, Kilimani, Nairobi     110 m²
# 4         Lavington       Gitanga Rd Nairobi, Lavington, Nairobi     200 m²
#
#   furnished rental_rate                                     property_price  \
# 0     false         day  KSh 12 000\r\n                            per day
# 1     false         day   KSh 4 500\r\n                            per day
# 2     false         day  KSh 12 000\r\n                            per day
# 3     false         day  KSh 10 000\r\n                            per day
# 4     false         day   KSh 9 000\r\n                            per day
#
#                 last_scraped
# 0 2024-09-10 19:03:57.662506
# 1 2024-09-10 19:03:57.667252
# 2 2024-09-10 19:03:57.669368
# 3 2024-09-10 19:03:57.671254
# 4 2024-09-10 19:03:57.673129

# %% [markdown]
# ### **b. Apartmensts for Sale in Nairobi**

# %%
# Initialize DataFrame outside the loop
bigdata = pd.DataFrame()

for page in trange(1,101):
    counties = ['nairobi']
    
    for county in counties:
        # specify website url 
        url = 'https://www.property24.co.ke/property-for-sale-in-'+str(county)+'-p95?propertytypes=apartments-flats,townhouses&Page=' + str(page)
        req = requests.get(url).text 
        soup = BeautifulSoup(req,'lxml')
        listings = soup.find_all('span',class_='p24_content')

        for listing in listings:
            try:
                property_title = listing.find('span',class_='p24_propertyTitle').text.strip()
                property_availability = 'For Sale'
                property_location = listing.find('span',class_='p24_location').text.strip()
                property_address = listing.find('span',class_='p24_address').text.strip()
                floor_size = listing.find('span',class_='p24_size').text.strip()
                property_price = listing.find('span',class_='p24_price').text.strip()
                rental_rate = np.NAN
                furnished = np.NAN
                last_scraped = datetime.now()
                
                # Create DataFrame
                data = pd.DataFrame({
                    'county':[county],
                    'property_title':[property_title],
                    'property_availability':[property_availability],
                    'property_location':[property_location],
                    'property_address':[property_address],
                    'floor_size':[floor_size],
                    'furnished':[furnished],
                    'rental_rate':[rental_rate],
                    'property_price':[property_price],
                    'last_scraped':[last_scraped]
                })

                # Append data to bigdata DataFrame
                bigdata = pd.concat([bigdata,data],ignore_index=True)
                
            except Exception as e:
                pass   

# Handle Database Import Error
table_id = 'project-adrian-julius-aluoch.cronjobs.real_estate_data'
job = client.load_table_from_dataframe(bigdata,table_id)
while job.state != 'DONE':
    time.sleep(4)
    job.reload()
    print(f"Data Upload Status : {job.state}")
# Out:
# 100%|██████████| 100/100 [02:58<00:00,  1.78s/it]
# Data Upload Status : DONE

# %%
# Shape of Data Collected
bigdata.shape
# Out:
# (1913, 10)

# %%
# Apartments for Sale in Nairobi
bigdata.head()
# Out:
#     county              property_title property_availability  \
# 0  nairobi         4 Bedroom Townhouse              For Sale
# 1  nairobi  4 Bedroom Apartment / Flat              For Sale
# 2  nairobi  1 Bedroom Apartment / Flat              For Sale
# 3  nairobi  2 Bedroom Apartment / Flat              For Sale
# 4  nairobi  4 Bedroom Apartment / Flat              For Sale
#
#   property_location                         property_address floor_size  \
# 0             Karen                           Karen, Nairobi    4 acres
# 1        Kileleshwa  Kileleshwa Nairobi, Kileleshwa, Nairobi     250 m²
# 2     Ongata Rongai                   Ongata Rongai, Nairobi      44 m²
# 3        Kileleshwa                      Kileleshwa, Nairobi     118 m²
# 4          Kilimani           Likoni lane, Kilimani, Nairobi   147.5 m²
#
#    furnished  rental_rate   property_price               last_scraped
# 0        NaN          NaN  KSh 335 400 000 2024-09-10 19:26:32.607510
# 1        NaN          NaN   KSh 26 000 000 2024-09-10 19:26:32.610171
# 2        NaN          NaN    KSh 2 960 000 2024-09-10 19:26:32.613069
# 3        NaN          NaN   KSh 12 000 000 2024-09-10 19:26:32.615605
# 4        NaN          NaN   KSh 14 800 000 2024-09-10 19:26:32.618667

# %% [markdown]
# ### **c. Apartment for Rent in Mombasa**

# %%
# Initialize DataFrame outside the loop
bigdata = pd.DataFrame()

for page in trange(1,101):
    counties = ['mombasa']
    furnished = ['true','false']
    rental_rates = ['day','month','week','year']
    
    for county in counties:
        for furnish in furnished:
            for rate in rental_rates:
                
                # specify website url 
                url = 'https://www.property24.co.ke/property-to-rent-in-'+str(county)+'-p93?rentalterm='+str(rate)+'&isfurnished='+str(furnish)+'&propertytypes=apartments-flats,townhouses&Page=' + str(page)
                req = requests.get(url).text 
                soup = BeautifulSoup(req,'lxml')
                listings = soup.find_all('span',class_='p24_content')

                for listing in listings:
                    try:
                        property_title = listing.find('span',class_='p24_propertyTitle').text.strip()
                        property_availability = 'For Rent'
                        property_location = listing.find('span',class_='p24_location').text.strip()
                        property_address = listing.find('span',class_='p24_address').text.strip()
                        floor_size = listing.find('span', class_='p24_size', title='Floor Size').text.strip()
                        furnished = furnish
                        rental_rate = rate
                        property_price = listing.find('span',class_='p24_price').text.strip()
                        last_scraped = datetime.now()
                        
                        # Create DataFrame
                        data = pd.DataFrame({
                            'county':[county],
                            'property_title':[property_title],
                            'property_availability':[property_availability],
                            'property_location':[property_location],
                            'property_address':[property_address],
                            'floor_size':[floor_size],
                            'furnished':[furnished],
                            'rental_rate':[rental_rate],
                            'property_price':[property_price],
                            'last_scraped':[last_scraped]
                        })

                        # Append data to bigdata DataFrame
                        bigdata = pd.concat([bigdata,data],ignore_index=True)
                        
                    except Exception as e:
                        pass            

# Handle Database Import Error
table_id = 'project-adrian-julius-aluoch.cronjobs.real_estate_data'
job = client.load_table_from_dataframe(bigdata,table_id)
while job.state != 'DONE':
    time.sleep(4)
    job.reload()
    print(f"Data Upload Status : {job.state}")
# Out:
# 100%|██████████| 100/100 [20:44<00:00, 12.45s/it]
# Data Upload Status : DONE

# %%
# Shape of Data Collected
bigdata.shape
# Out:
# (1729, 10)

# %%
# Apartments for Rent in Mombasa
bigdata.head()
# Out:
#     county              property_title property_availability  \
# 0  mombasa  3 Bedroom Apartment / Flat              For Rent
# 1  mombasa  2 Bedroom Apartment / Flat              For Rent
# 2  mombasa  2 Bedroom Apartment / Flat              For Rent
# 3  mombasa  4 Bedroom Apartment / Flat              For Rent
# 4  mombasa  3 Bedroom Apartment / Flat              For Rent
#
#   property_location                         property_address floor_size  \
# 0             Nyali   Mombasa Mombasa County, Nyali, Mombasa     240 m²
# 1    Mombasa Island  Shanzu Mombasa, Mombasa Island, Mombasa     140 m²
# 2             Nyali             1058 1st Ave, Nyali, Mombasa     200 m²
# 3             Nyali     Bungalows Rd Mombasa, Nyali, Mombasa    2700 m²
# 4             Nyali        XP64+VRJ Links Rd, Nyali, Mombasa    1800 m²
#
#   furnished rental_rate                                     property_price  \
# 0     false         day  KSh 20 000\r\n                            per day
# 1     false         day  KSh 14 000\r\n                            per day
# 2     false         day  KSh 12 000\r\n                            per day
# 3     false       month                                        KSh 150 000
# 4     false       month                                         KSh 55 000
#
#                 last_scraped
# 0 2024-09-10 19:29:41.109873
# 1 2024-09-10 19:29:41.112039
# 2 2024-09-10 19:29:41.114036
# 3 2024-09-10 19:29:42.700735
# 4 2024-09-10 19:29:42.703596

# %% [markdown]
# ### **d. Apartments for Sale in Mombasa**

# %%
# Initialize DataFrame outside the loop
bigdata = pd.DataFrame()

# specify website url 
for page in trange(1,101):
    counties = ['mombasa']
    for county in counties:
        url = 'https://www.property24.co.ke/property-for-sale-in-'+str(county)+'-p93?propertytypes=apartments-flats,townhouses&Page=' + str(page)
        req = requests.get(url).text 
        soup = BeautifulSoup(req,'lxml')

        listings = soup.find_all('span',class_='p24_content')

        for listing in listings:
            try:
                property_title = listing.find('span',class_='p24_propertyTitle').text.strip()
                property_availability = 'For Sale'
                property_location = listing.find('span',class_='p24_location').text.strip()
                property_address = listing.find('span',class_='p24_address').text.strip()
                floor_size = listing.find('span',class_='p24_size').text.strip()
                property_price = listing.find('span',class_='p24_price').text.strip()
                rental_rate = np.NAN
                furnished = np.NAN
                last_scraped = datetime.now()
                data = pd.DataFrame({
                    'county':[county],
                    'property_title':[property_title],
                    'property_availability':[property_availability],
                    'property_location':[property_location],
                    'property_address':[property_address],
                    'floor_size':[floor_size],
                    'furnished':[furnished],
                    'rental_rate':[rental_rate],
                    'property_price':[property_price],
                    'last_scraped':[last_scraped]
                })

                # Append data to bigdata DataFrame
                bigdata = pd.concat([bigdata,data],ignore_index=True)
                
            except Exception as e:
                pass     

# Handle Database Import Error
table_id = 'project-adrian-julius-aluoch.cronjobs.real_estate_data'
job = client.load_table_from_dataframe(bigdata,table_id)
while job.state != 'DONE':
    time.sleep(4)
    job.reload()
    print(f"Data Upload Status : {job.state}")
# Out:
# 100%|██████████| 100/100 [02:43<00:00,  1.63s/it]
# Data Upload Status : DONE

# %%
# Shape of Data Collected
bigdata.shape
# Out:
# (1585, 10)

# %%
# Apartments for Sale in Mombasa
bigdata.head()
# Out:
#     county              property_title property_availability  \
# 0  mombasa  3 Bedroom Apartment / Flat              For Sale
# 1  mombasa  2 Bedroom Apartment / Flat              For Sale
# 2  mombasa  3 Bedroom Apartment / Flat              For Sale
# 3  mombasa  3 Bedroom Apartment / Flat              For Sale
# 4  mombasa  2 Bedroom Apartment / Flat              For Sale
#
#   property_location                         property_address floor_size  \
# 0             Nyali  XP99+52X Mount Kenya Rd, Nyali, Mombasa    2700 m²
# 1             Nyali     Greenwood Dr Mombasa, Nyali, Mombasa    1600 m²
# 2             Nyali                           Nyali, Mombasa     172 m²
# 3             Nyali         Beach Rd Mombasa, Nyali, Mombasa    1700 m²
# 4             Nyali         XPHF+3JG 1st Ave, Nyali, Mombasa    1400 m²
#
#    furnished  rental_rate  property_price               last_scraped
# 0        NaN          NaN  KSh 23 000 000 2024-09-10 19:50:25.860548
# 1        NaN          NaN   KSh 7 500 000 2024-09-10 19:50:25.863897
# 2        NaN          NaN  KSh 17 500 000 2024-09-10 19:50:25.866893
# 3        NaN          NaN   KSh 7 750 000 2024-09-10 19:50:25.869439
# 4        NaN          NaN   KSh 8 500 000 2024-09-10 19:50:25.871793

# %% [markdown]
# ### **Basic Data Cleaning**

# %%
# Define SQL Query to Retrieve Real Estate Data from Google Cloud BigQuery
sql = (
       'SELECT *'
       'FROM `cronjobs.real_estate_data`'
       )

# Run SQL Query
data = client.query(sql).to_dataframe()
print(f'Rows of Real Estate Data in Google BigQuery : {data.shape[0]:,.0f}\nCols of Real Estate Data in Google BigQuery : {data.shape[1]:,.0f}')
# Out:
# Rows of Real Estate Data in Google BigQuery : 12,395
# Cols of Real Estate Data in Google BigQuery : 10

# %%
# Check Total Number of Duplicate Records
duplicated = data.duplicated(subset=[
       'county', 'property_title', 'property_availability',
       'property_location', 'property_address', 'floor_size', 
       'furnished', 'rental_rate', 'property_price'
                                    ]).sum()

# Remove Duplicate Records
data.drop_duplicates(subset=[
       'county', 'property_title', 'property_availability',
       'property_location', 'property_address', 'floor_size', 
       'furnished', 'rental_rate', 'property_price'
                            ],inplace=True)

# Display Initial & Final Number of Duplicate Records
print(f"Initial Shape of Dataset : {data.shape}\nTotal Duplicate Records : {duplicated:,.0f}\nFinal Shape of Dataset : {data.shape}")
# Out:
# Initial Shape of Dataset : (5495, 10)
# Total Duplicate Records : 6,900
# Final Shape of Dataset : (5495, 10)

# %%
# Drop Original Real Estate Table 
table_id = 'project-adrian-julius-aluoch.cronjobs.real_estate_data'
client.delete_table(table_id)

# Upload Final Real Estate Table
job = client.load_table_from_dataframe(data,table_id)
while job.state != 'DONE':
    time.sleep(1)
    job.reload()
    print(f'Real Estate Data Update : {job.state}')
# Out:
# Real Estate Data Update : RUNNING
# Real Estate Data Update : DONE

# %% [markdown]
# ### **Save the Results to CSV**

# %%
data.to_csv('real estate.csv',index=False)
print(f'Real Estate Data Successfully Saved to CSV.')
# Out:
# Real Estate Data Successfully Saved to CSV.

# %% [markdown]
# ### **Display the Real Estate Data**

# %%
data.iloc[:100].sort_values(by='last_scraped',ascending=False).reset_index(drop=True)
# Out:
#      county       property_title property_availability property_location  \
# 0   nairobi     Apartment / Flat              For Sale         Westlands
# 1   nairobi     Apartment / Flat              For Sale          Syokimau
# 2   nairobi     Apartment / Flat              For Sale        Kileleshwa
# 1                 Off Mombasa road, Syokimau, Nairobi       30 m²      None
# 2                     Kileleshwa, Kileleshwa, Nairobi       40 m²      None
# 3               Off Naivasha road, Dagoretti, Nairobi       23 m²      None
# 4             Near Kasuku Centre, Kileleshwa, Nairobi       40 m²      None
# 5             Mombasa Road Nairobi, Syokimau, Nairobi       47 m²      None
# 6             Mombasa Road Nairobi, Syokimau, Nairobi       47 m²      None
# 7            Kerarapon Drive Road, Kerarapon, Nairobi    14 acres      None
# 8                  Langata Rd Langata, Karen, Nairobi      200 m²     false
# 9                      Lenana road, Kilimani, Nairobi     1200 m²     false
# 10                     Denis Pritt, Kilimani, Nairobi     1800 m²     false
# 11               Dennis Pritt road, Kilimani, Nairobi     1800 m²     false
# 12                 Peponi Rd Nairobi, Peponi, Nairobi      130 m²     false
# 13                  QQHX+Q72 Kitisuru, Runda, Nairobi      300 m²     false
# 14                     Red Hill Rd KE, Nyari, Nairobi      250 m²     false
# 15                Kilimani Nairobi, Kilimani, Nairobi      100 m²     false
# 16                                     Runda, Nairobi      300 m²     false
# 17                 Ridgeways Road, Ridgeways, Nairobi      297 m²     false
# 18    Off Lower Kabete Nairobi, Lower Kabete, Nairobi      280 m²     false
# 19           Riverside Dr Nairobi, Riverside, Nairobi      130 m²     false
# 20           Riverside Dr Nairobi, Riverside, Nairobi      130 m²     false
# 21                             Valley Arcade, Nairobi       19 m²     false
# 22        Kilimani Estate Kilimani, Kilimani, Nairobi       39 m²     false
# 23      Argwings Kodhek Rd Nairobi, Kilimani, Nairobi       39 m²     false
# 24        Kilimani Estate Kilimani, Kilimani, Nairobi       39 m²     false
# 25                Kilimani Nairobi, Kilimani, Nairobi      150 m²     false
# 26           Ndege Road Nakuru County, Karen, Nairobi     1200 m²     false
# 27                    Upper Hill, Upper Hill, Nairobi       70 m²     false
# 28        Ring Rd Kilimani Nairobi, Kilimani, Nairobi       39 m²     false
# 29                Ring Rd Kilimani, Kilimani, Nairobi       39 m²     false
# 30    Ring Rd Westlands Ln Nairobi, Kilimani, Nairobi       39 m²     false
# 31               Wood Ave Kilimani, Kilimani, Nairobi        5 m²     false
# 32        Kilimani Estate Kilimani, Kilimani, Nairobi       39 m²     false
# 33                             Garden Estate, Nairobi   0.5 acres      None
# 34                              nyali, Nyali, Mombasa     2000 m²     false
# 35                     WMWW+RFF Nyali, Nyali, Mombasa     5000 m²      None
# 36                   2PVX+H6H Mtwapa, Mtwapa, Mombasa     4000 m²      None
# 37                      Nyali Mombasa, Nyali, Mombasa     5000 m²      None
# 38                     WMWW+C5G Nyali, Nyali, Mombasa     5000 m²      None
# 39               XMFP+42J Kisauni, Bombolulu, Mombasa     5000 m²      None
# 40                 WMVX+35J Corral Dr, Nyali, Mombasa     5000 m²      None
# 41                  XP33+8FM Beach Rd, Nyali, Mombasa     5000 m²      None
# 42                               Githurai 44, Nairobi     0.03 ha      None
# 43                              Nyali, Nyali, Mombasa     2000 m²     false
# 44           Lavington Kileleshwa, Lavington, Nairobi   0.5 acres      None
# 45                        Karen Karen, Karen, Nairobi   0.5 acres      None
# 46                      Westlands, Westlands, Nairobi       41 m²      None
# 47                Kilimani Nairobi, Kilimani, Nairobi      100 m²     false
# 48                                    Mtwapa, Mombasa      167 m²      None
# 49                              Nyali, Nyali, Mombasa      450 m²      None
# 50                 Malindi Rd Mtwapa, Mtwapa, Mombasa     1800 m²      None
# 51             Zion Stage Malindi Rd, Mtwapa, Mombasa     2000 m²      None
# 52                   3P7W+R3W Mtwapa, Mtwapa, Mombasa     1800 m²      None
# 53                   3PFR+84F Mtwapa, Mtwapa, Mombasa     1750 m²      None
# 54                    XP64+PQ Mombasa, Nyali, Mombasa     2500 m²      None
# 55                  88447 Malindi Rd, Mtwapa, Mombasa     1750 m²      None
# 56           Diani Beach Kwale County, Diani, Mombasa      130 m²      None
# 57                   Links Rd Mombasa, Nyali, Mombasa     2000 m²      None
# 58                                   Bamburi, Mombasa  0.02 acres      None
# 59                              nyali, Nyali, Mombasa      750 m²      None
# 60                              Nyali, Nyali, Mombasa      450 m²      None
# 61                                     Nyali, Mombasa       42 m²      None
# 62                            Mtwapa, Mtwapa, Mombasa     1800 m²      None
# 63                     Off links road, Nyali, Mombasa     2500 m²      None
# 64             Mtwapa Mombasa County, Mtwapa, Mombasa      870 m²      None
# 65                                    Mtwapa, Mombasa     2700 m²      None
# 66                              nyali, Nyali, Mombasa     2500 m²     false
# 67                                 Westlands, Nairobi       41 m²      None
# 68             Kitengela Rd Nairobi, Langata, Nairobi        2 m²     false
# 69                     Runda Kitisuru, Runda, Nairobi      180 m²     false
# 70                   Othaya Road, Kileleshwa, Nairobi       50 m²     false
# 71         Muthaiga North Rd, Muthaiga North, Nairobi      230 m²     false
# 72  Muthaiga North Rd Nairobi, Muthaiga North, Nai...      200 m²     false
# 73                Kilimani Nairobi, Kilimani, Nairobi      100 m²     false
# 74              Off Mbaazi Avenue, Lavington, Nairobi       50 m²     false
# 75                Kilimani Nairobi, Kilimani, Nairobi      100 m²     false
# 76                      Lavington, Lavington, Nairobi      180 m²     false
# 77                    Utange Mombasa, Utange, Mombasa      500 m²      None
# 78                              nyali, Nyali, Mombasa     2500 m²     false
# 79                 Malindi Rd Mtwapa, Mtwapa, Mombasa     1650 m²     false
# 80                   XP62+CVC Mombasa, Nyali, Mombasa      200 m²     false
# 81                              Nyali, Nyali, Mombasa     2000 m²     false
# 82                               Mombasa CBD, Mombasa     1500 m²     false
# 83                   Links Rd Mombasa, Nyali, Mombasa       80 m²     false
# 84                  Cement Rd Mkomani, Nyali, Mombasa     6000 m²     false
# 85                              Nyali, Nyali, Mombasa     2000 m²     false
# 86                              Nyali, Nyali, Mombasa     2500 m²     false
# 87             Unnamed Road Nairobi, South C, Nairobi      169 m²      None
# 88             Kingara Rd Nairobi, Lavington, Nairobi       94 m²      None
# 89                      Westlands, Westlands, Nairobi       41 m²      None
# 90           Off Tabere Crescent, Kileleshwa, Nairobi       40 m²      None
# 91                      Westlands, Westlands, Nairobi       33 m²      None
# 92                     Wood Avenue, Kilimani, Nairobi       45 m²      None
# 93                Kilimani Nairobi, Kilimani, Nairobi       53 m²      None
# 94                Off Mombasa Road, Syokimau, Nairobi       44 m²      None
# 95                Off Rhapta road, Westlands, Nairobi       41 m²      None
# 96               Off Gitanga road, Lavington, Nairobi       45 m²      None
# 97        Kilimani Estate Kilimani, Kilimani, Nairobi       39 m²     false
# 98        Off Argwings Kodhek road, Kilimani, Nairobi       40 m²     false
# 99                      Ridgeways, Ridgeways, Nairobi      175 m²     false
#
#    rental_rate                                     property_price  \
# 0         None                                      KSh 8 500 000
# 1         None                                      KSh 3 000 000
# 2         None                                      KSh 4 500 000
# 3         None                                      KSh 2 300 000
# 4         None                                      KSh 4 500 000
# 5         None                                      KSh 3 900 000
# 6         None                                      KSh 4 700 000
# 7         None                                    KSh 700 000 000
# 8        month                                         KSh 25 000
# 9        month                                         KSh 60 000
# 10       month                                         KSh 60 000
# 11       month                                         KSh 65 000
# 12       month                                        KSh 195 000
# 13       month                                        KSh 160 000
# 14       month                                        KSh 300 000
# 15       month                                         KSh 40 000
# 16       month                                        KSh 257 180
# 17       month                                        KSh 390 000
# 18       month                                        KSh 300 000
# 19       month                                        KSh 100 000
# 20       month                                         KSh 75 000
# 21         day  KSh 15 600\r\n                            per day
# 22         day   KSh 5 000\r\n                            per day
# 23         day   KSh 6 000\r\n                            per day
# 24         day   KSh 6 000\r\n                            per day
# 25       month                                        KSh 110 000
# 26       month                                        KSh 220 000
# 27         day   KSh 6 500\r\n                            per day
# 28         day   KSh 4 500\r\n                            per day
# 29         day   KSh 4 500\r\n                            per day
# 30         day   KSh 4 500\r\n                            per day
# 31         day   KSh 5 000\r\n                            per day
# 32         day   KSh 4 500\r\n                            per day
# 33        None                                     KSh 48 000 000
# 34       month                                         KSh 65 000
# 35        None                                     KSh 30 000 000
# 36        None                                     KSh 55 000 000
# 37        None                                     KSh 13 000 000
# 38        None                                     KSh 28 000 000
# 39        None                                     KSh 15 000 000
# 40        None                                     KSh 45 000 000
# 41        None                                     KSh 35 000 000
# 42        None                                     KSh 20 000 000
# 43       month                                         KSh 65 000
# 44        None                                      KSh 4 690 000
# 45        None                                    KSh 105 000 000
# 46        None                                      KSh 8 300 000
# 47       month                                        KSh 100 000
# 48        None                                      KSh 8 500 000
# 49        None                                      KSh 4 200 000
# 50        None                                      KSh 7 500 000
# 51        None                                      KSh 7 900 000
# 52        None                                      KSh 7 500 000
# 53        None                                      KSh 7 500 000
# 54        None                                      KSh 5 900 000
# 55        None                                      KSh 7 500 000
# 56        None                                     KSh 20 000 000
# 57        None                                      KSh 7 500 000
# 58        None                                     KSh 12 000 000
# 59        None                                      KSh 4 100 000
# 60        None                                      KSh 4 100 000
# 61        None                                      KSh 4 200 000
# 62        None                                      KSh 8 500 000
# 63        None                                     KSh 23 000 000
# 64        None                                      KSh 7 300 000
